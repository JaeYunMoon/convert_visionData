# %%
import os 
import json 

file = "C:/Users/sim2real/Desktop/personalProject/data_solution_ver2/data/labels/20230711-090930.879513com1.json"

with open(file) as f:
    data = json.load(f)
print(data)
# Out:
# {'img_name': '20230711-090930.879513com1', 'height': 1080, 'width': 1920, 'annotations': [{'category_name': 'Lying', 'unique_id': 'THlpbmdJR0VoTUNoTUZxVw==', 'box2d': [1049.9246826171875, 1280.012451171875, 600.5172119140625, 824.0616455078125], 'rbox2d': [46.781742095947266, 1153.0845947265625, 725.53369140625, 158.77197265625, 233.26271057128906], 'box3DPX': [[1305.4757080078125, 698.4066162109375], [1277.2489013671875, 683.8213500976562], [1141.2557373046875, 880.6822509765625], [1126.5006103515625, 851.3124389648438], [1187.66650390625, 593.2247314453125], [1169.0257568359375, 587.2206420898438], [1023.541015625, 776.339111328125], [1018.3575439453125, 755.419189453125]], 'keypoint_name': ['nose', 'hip', 'neck', 'body_center', 'key_5', 'Key_6', 'key_7', 'key_8', 'K9'], 'keypoint2d': [[1055.652587890625, 752.6658325195312], [1095.8040771484375, 796.36767578125], [1165.05517578125, 801.0830688476562], [1209.2298583984375, 779.2807006835938], [1246.725830078125, 729.5525512695312], 
# ...
